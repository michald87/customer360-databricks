# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.erp;

# %%
# %sql
CREATE OR REPLACE TABLE customer (
  customer_id BIGINT COMMENT 'Unique customer identifier',
  first_name STRING COMMENT 'Customer first name',
  last_name STRING COMMENT 'Customer last name',
  pesel STRING COMMENT 'Polish national identification number',
  birth_date DATE COMMENT 'Date of birth',
  email STRING COMMENT 'Email address',
  phone STRING COMMENT 'Phone number',
  address STRING COMMENT 'Street address',
  city STRING COMMENT 'City',
  postal_code STRING COMMENT 'Postal/ZIP code',
  country STRING COMMENT 'Country',
  registration_date TIMESTAMP COMMENT 'Account registration date',
  customer_status STRING COMMENT 'Customer status (active, inactive, suspended)',
  last_purchase_date DATE COMMENT 'Date of last purchase',
  total_purchases DECIMAL(10,2) COMMENT 'Total purchase amount'
);

# %%
# %sql
insert into customer (customer_id, first_name, last_name, pesel, birth_date, email, phone, address, city, postal_code, country, registration_date, customer_status, last_purchase_date, total_purchases) values
(1, 'John', 'Doe', '12345678901', '1980-01-01', 'john.doe@example.com', '1234567890', '123 Main St', 'New York', '10001', 'USA', '2010-01-01 00:00:00', 'active', '2022-01-01', 100.00),
(2, 'Jane', 'Doe', '12345678902', '1985-05-05', 'jane.doe@example.com', '0987654321', '456 Elm St', 'Los Angeles', '90001', 'USA', '2012-01-01 00:00:00', 'inactive', '2021-01-01', 50.00),
(3, 'Alice', 'Smith', '12345678903', '1990-07-07', 'alice.smith@example.com', '1112223333', '789 Oak St', 'Chicago', '60601', 'USA', '2015-01-01 00:00:00', 'suspended', '2020-01-01', 75.00),
(4, 'Bob', 'Johnson', '12345678904', '1995-09-09', 'bob.johnson@example.com', '4445556666', '321 Pine St', 'Houston', '77001', 'USA', '2018-01-01 00:00:00', 'active', '2022-01-01', 120.00),
(5, 'Charlie', 'Williams', '12345678905', '2000-11-11', 'charlie.williams@example.com', '7778889999', '654 Maple St', 'Phoenix', '85001', 'USA', '2020-01-01 00:00:00', 'active', '2022-01-01', 150.00),
(6, 'David', 'Brown', '12345678906', '2005-01-01', 'david.brown@example.com', '1112223333', '987 Cedar St', 'Philadelphia', '19101', 'USA', '2021-01-01 00:00:00', 'active', '2022-01-01', 200.00),
(7, 'Eve', 'Davis', '12345678907', '2010-03-03', 'eve.davis@example.com', '4445556666', '654 Pine St', 'San Francisco', '94101', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 250.00),
(8, 'Frank', 'Miller', '12345678908', '2015-05-05', 'frank.miller@example.com', '7778889999', '321 Oak St', 'Seattle', '98101', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 300.00),
(9, 'Grace', 'Taylor', '12345678909', '2020-07-07', 'grace.taylor@example.com', '1112223333', '789 Maple St', 'Austin', '78701', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 350.00),
(10, 'Henry', 'Anderson', '12345678910', '2025-09-09', 'henry.anderson@example.com', '4445556666', '456 Pine St', 'Dallas', '75201', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 400.00),
(11, 'Ivy', 'Thomas', '12345678911', '2030-11-11', 'ivy.thomas@example.com', '7778889999', '987 Oak St', 'Portland', '97201', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 450.00),
(12, 'Jack', 'Jackson', '12345678912', '2035-01-01', 'jack.jackson@example.com', '1112223333', '654 Pine St', 'Boston', '02101', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 500.00),
(13, 'Kate', 'White', '12345678913', '2040-03-03', 'kate.white@example.com', '4445556666', '321 Maple St', 'Miami', '33101', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 550.00),
(14, 'Liam', 'Harris', '12345678914', '2045-05-05', 'liam.harris@example.com', '7778889999', '789 Oak St', 'Atlanta', '30301', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 600.00),
(15, 'Mia', 'Garcia', '12345678915', '2050-07-07', 'mia.garcia@example.com', '1112223333', '456 Pine St', 'Denver', '80201', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 650.00),
(16, 'Noah', 'Martinez', '12345678916', '2055-09-09', 'noah.martinez@example.com', '4445556666', '987 Maple St', 'San Diego', '92101', 'USA', '2022-01-01 00:00:00', 'active', '2022-01-01', 700.00);
